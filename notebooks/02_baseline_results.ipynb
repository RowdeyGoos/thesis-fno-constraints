# %% [markdown]
# # Baseline Results
#
# This notebook analyzes the baseline FNO model performance.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# %% [markdown]
# ## Load Results

# %%
# TODO: Load and analyze baseline results

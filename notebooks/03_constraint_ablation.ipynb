# %% [markdown]
# # Constraint Ablation Study
#
# This notebook performs ablation studies on different physical constraints.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from pathlib import Path

# %% [markdown]
# ## Compare Constraint Methods

# %%
# TODO: Ablation study analysis

# %% [markdown]
# # Data Exploration
#
# This notebook explores the datasets used in the thesis experiments.

# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
from pathlib import Path

# %% [markdown]
# ## Load Dataset

# %%
# TODO: Load and visualize dataset
